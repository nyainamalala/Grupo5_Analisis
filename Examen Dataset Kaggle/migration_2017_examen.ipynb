# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/FuentesOriginales/Kaggle/InternationalMigrationData20002020/migration_2017.csv')
df.head(10)
# Out:
#           Country
# 0       Australia  \
# 1         Austria
# 2         Belgium
# 3          Canada
# 4           Chile
# 5  Czech Republic
# 6         Denmark
# 7         Estonia
# 8         Finland
# 9          France
#
#    Acquisition of nationality by country of former nationality(Total)
# 0                                           137750.0                   \
# 1                                             9125.0
# 2                                            37401.0
# 3                                           105813.0
# 4                                             2976.0
# 5                                             6440.0
# 6                                             7272.0
# 7                                              882.0
# 8                                            12219.0
# 9                                           114274.0
#
#    Acquisition of nationality by country of former nationality(Women)
# ...

# %%
stock_by_nationality = df['Stock of foreign population by nationality(Total)'].values
stock_by_nationality
# Out:
# array([      nan,  1341930.,  1366500.,       nan,   952711.,   493441.,
#          484986.,   212213.,   243639.,  4704000., 10039080.,   538400.,
#          151132.,    30275.,   566600.,       nan,  5047028.,  2382822.,
#         1161677.,   279446.,   281497.,   381770.,   972300.,       nan,
#          559227.,   210328.,   397731.,    69695.,   114438.,  4419455.,
#          851949.,  2029527.,   816410.,  6137000., 22415312.])

# %% [markdown]
# # Detectar valores faltantes

# %%
df.isnull().sum()
# Out:
# Country                                                                0
# Acquisition of nationality by country of former nationality(Total)     2
# Acquisition of nationality by country of former nationality(Women)     8
# Inflows of asylum seekers by nationality(Total)                        0
# Inflows of foreign population by nationality(Total)                    0
# Inflows of foreign population by nationality(Women)                    3
# Inflows of foreign workers by nationality(Total)                      12
# Inflows of foreign workers by nationality(Women)                      17
# Outflows of foreign population by nationality(Total)                  10
# Outflows of foreign population by nationality(Women)                  13
# Stock of foreign population by nationality(Total)                      4
# Stock of foreign population by nationality(Women)                      8
# Stock of foreign-born population by country of birth(Total)           10
# ...

# %% [markdown]
# ## propuesta: eliminar columnas por sexo, y quedarnos con totales. suprimir columnas 2,5,7,9,11 y 13
# ## sustituir nan en resto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Country                                                             35 non-null     object
#  1   Acquisition of nationality by country of former nationality(Total)  33 non-null     float64
#  2   Acquisition of nationality by country of former nationality(Women)  27 non-null     float64
#  3   Inflows of asylum seekers by nationality(Total)                     35 non-null     float64
#  4   Inflows of foreign population by nationality(Total)                 35 non-null     float64
#  5   Inflows of foreign population by nationality(Women)                 32 non-null     float64
#  6   Inflows of foreign workers by nationality(Total)                    23 non-null     float64
# ...

# %% [markdown]
# # imputar valores faltantes. conservamos original. buscamos media, mediana ... para ver con qué los sustituimos

# %%
df2 = df.copy()

# %% [markdown]
# ## columna stock_by_nationality y sotck_by_birth

# %%
mean = df2['Stock of foreign population by nationality(Total)'].mean()
median = df2['Stock of foreign population by nationality(Total)'].median()
print(f"mean: {mean}")
print(f"median: {median}")
# Out:
# mean: 2246855.4516129033
# median: 566600.0

# %%
mean = df2['Stock of foreign-born population by country of birth(Total)'].mean()
median = df2['Stock of foreign-born population by country of birth(Total)'].median()
print(f"mean: {mean}")
print(f"median: {median}")
# Out:
# mean: 4441591.44
# median: 1784497.0
